# %%
#Import pandas for EDA
import pandas as pd

# %%
#Read dataset
tweets_dataset = pd.read_csv('C:/Users/estoe/Downloads/Twitter Exercise- BI Exercise/Twitter Exercise- BI Exercise/Tweets DataViz Dataset - TweetsDataset.csv')

#Count rows and cols
tweets_dataset.shape
# Out:
# (1726, 25)

# %%
#Exploratory Sample
tweets_dataset.head()
# Out:
#         user_id     status_id    created_at      screen_name  \
# 0  1.150000e+18  1.430000e+18  Aug 20, 2021         sab_loos
# 1  1.758731e+07  1.430000e+18  Aug 27, 2021          avyfain
# 2  9.050000e+17  1.430000e+18  Aug 30, 2021     observablehq
# 3  9.050000e+17  1.420000e+18  Aug 22, 2021     observablehq
# 4  1.192883e+08  1.430000e+18   Aug 4, 2021  marissaxdexleon
#
#                                                 text               source  \
# 0  So blown away by all the #disaster #dataviz pr...  Twitter for Android
# 1  New census data means there's a lot of cool #d...      Twitter Web App
# 2  We're thrilled to announce the winners of our ...      Twitter Web App
# 3  Tag someone who you think might be interested ...            TweetDeck
# 4  Descripción gráfica de la variante Delta https...   Twitter for iPhone
#
#    reply_to_status_id  reply_to_user_id  is_retweet  favorite_count  ...  \
# 0                 NaN               NaN           0               6  ...
# ...

# %%
#Basic info about dataset
tweets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1726 entries, 0 to 1725
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               1726 non-null   float64
#  1   status_id             1726 non-null   float64
#  2   created_at            1726 non-null   object
#  3   screen_name           1726 non-null   object
#  4   text                  1726 non-null   object
#  5   source                1726 non-null   object
#  6   reply_to_status_id    229 non-null    float64
#  7   reply_to_user_id      236 non-null    float64
#  8   is_retweet            1726 non-null   int64
#  9   favorite_count        1726 non-null   int64
#  10  retweet_count         1726 non-null   int64
#  11  lang                  1726 non-null   object
#  12  name                  1726 non-null   object
#  13  description           1518 non-null   object
#  14  followers_count       1726 non-null   int64
# ...

# %%
# Nulls by column
print(tweets_dataset.isnull().sum())
# Out:
# user_id                    0
# status_id                  0
# created_at                 0
# screen_name                0
# text                       0
# source                     0
# reply_to_status_id      1497
# reply_to_user_id        1490
# is_retweet                 0
# favorite_count             0
# retweet_count              0
# lang                       0
# name                       0
# description              208
# followers_count            0
# friends_count              0
# statuses_count             0
# favourites_count           0
# account_created_at         0
# verified                   0
# sentiment_value            0
# sentiment_dictionary       0
# lat                        0
# lng                        0
# City                       0
# dtype: int64

# %%
#Descriptive statistics
tweets_dataset.describe()
# Out:
#             user_id     status_id  reply_to_status_id  reply_to_user_id  \
# count  1.726000e+03  1.726000e+03        2.290000e+02      2.360000e+02
# mean   4.937265e+17  1.428714e+18        1.428515e+18      4.853305e+17
# std    5.865759e+17  3.348771e+15        6.848997e+15      5.831544e+17
# min    5.061300e+04  1.420000e+18        1.340000e+18      6.957530e+05
# 25%    3.425170e+08  1.430000e+18        1.430000e+18      2.788340e+08
# 50%    2.787199e+09  1.430000e+18        1.430000e+18      2.493193e+09
# 75%    1.150000e+18  1.430000e+18        1.430000e+18      1.092500e+18
# max    1.430000e+18  1.430000e+18        1.430000e+18      1.420000e+18
#
#         is_retweet  favorite_count  retweet_count  followers_count  \
# count  1726.000000     1726.000000    1726.000000     1.726000e+03
# mean      0.621669        1.931054      99.880649     2.395300e+04
# std       0.485111       15.014443     249.962369     2.506550e+05
# ...
